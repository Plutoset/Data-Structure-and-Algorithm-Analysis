# %%
class LayerManager():
    def __init__(self):
        self.array = []
        self.length = len(self.array)
    def get(self,idx):
        return self.array[idx]
    def Insert(self,Input,idx = -1):
        if idx == -1:
            self.array.append(Input)
            self.length = len(self.array)
        else:
            self.array.insert(idx,Input)
            self.length = len(self.array)
    def Delete(self,idx):
        self.array.pop(idx)
        self.length = len(self.array)
    def Delete(self,elem):
        self.array.remove(elem)
        self.length = len(self.array)
    def Modify(self,Input,idx):
        self.array[idx] = Input
    def Sort(self):
        self.array = self.array.sort()

class Point():
    def __init__(self):
        self.array=[]
    def Insert(self,Input,idx = -1):
        if idx != -1 & idx < self.length:
            self.array.insert(idx,Input)  
            self.length = len(self.array)
        else:
            self.array.append(Input)
            self.length = len(self.array)
    def Delete(self,idx):
        try:
            del self.array(idx)
            self.length = len(self.array)
        except:
            print("Error! The input index is larger than the size of Points!")
    def Modify(self,Input,idx):
        try:
            self.array[idx] = Input
        except:
            print("Error! The input index is larger than the size of Points!")
    def Loop(self):

# %% [markdown]
# ### week 3

# %%
class List ():
    def  __init__(self,size):
          self.len=0
          self._array=[]*size
    def  indexOf(self, key):
        try:
            return self._array.index(key)
        except:
            print('Error! No such element in list!')
    def  get(self, index):
        try:
            return self._array[index]
        except:
            print('Error! Input index out of range!')
    def  insert(self, data,index):
        try:
            self._array.insert(index,data)
            self.len += 1
        except:
            print('Error! Input index out of range!')
    def  delete(self, index):
        try:
            del self._array[index]
            self.len -=1
        except:
            print("Error! Input index out of range!")
    def  print(self):
        print(self._array)

class Stack (List):
    def  __init__(self):
          super().__init__(self)
          self.top=-1
          self.bottom=-1 
    def  push(self, elem):
          super().insert(elem,self.len-1)
          self.top +=1
    def  pop(self):
           return super().delete(self,self.len-1)

# %%
class LNode():
    def  __init__(self,  data_, next_=None):
        self.data = data_
        self.next = next_
    def get(self):
        return self.data
    
class LList():
    def  __init__(self): 
        self._head = None

    def isEmpty(self):
        return self._head is None

    def insert(self, data, index):
        pn = self._head
        j = 0
        while (j<index) & (pn != None):
            pn = pn.next
            j += 1
        
        if pn == None:
            pn = LNode(data)
            self._head = pn
        else:
            pn = LNode(data)
            q = self.get(j)
            pn.next = q.next
            q.next = pn
        # print(pn.get())

    def get(self,index):
        pn = self._head
        j = 0
        while (j < index) & (pn !=None):
            pn = pn.next
            j += 1
        if j > 0:
            return pn.data
        else:
            return None

    def delete(self,index):
        pn = self._head
        j = 0
        while j < index-1:
            pn = pn.next
            if pn.next == None:
                break
            else:
                j += 1
        if (j == 0) or (pn.next == None):
            return False
        else:
            pn2 = pn.next
            pn.next = pn2.next
            return True

    def size(self):
        pn = self._head
        j = 0
        while pn !=None:
            pn = pn.next
            j += 1  
        return j
    def indexOf(self,key):             #based on 0
        head = self._head
        j = 0    
        if head != None:
            pn = head[j]
            if pn.data != key:
                pn = pn.next
                j += 1

a=LNode(1)
b=LNode(2)
a.next
llist = LList()
llist.insert(a,1)
llist.insert(b,2)
llist.get(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21908/659571964.py in <module>
#      78 llist.insert(a,1)
#      79 llist.insert(b,2)
# ---> 80 llist.get(1)
#
# ~\AppData\Local\Temp/ipykernel_21908/659571964.py in get(self, index)
#      37             j += 1
#      38         if j > 0:
# ---> 39             return pn.data
#      40         else:
#      41             return None
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
# a=LNode(1)
# b=LNode(2)
# b.next
# llist = LList()
llist.insert(a,1)
llist.insert(b,2)
# llist.get(1)
llist.size()
# Out:
# 1
